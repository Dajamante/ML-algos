# %%
# item based similarity recommander system

# %%
import numpy as np
import pandas as pd

# %%
columns_names = ['user_id','item_id','rating', 'timestamp']

# %%
df = pd.read_csv('u.data', sep='\t', names=columns_names)

# %%
df #a user id, an item id, the rating and at what time they gave the rating
# Out:
#         user_id  item_id  rating  timestamp
# 0             0       50       5  881250949
# 1             0      172       5  881250949
# 2             0      133       1  881250949
# 3           196      242       3  881250949
# 4           186      302       3  891717742
# ...         ...      ...     ...        ...
# 99998       880      476       3  880175444
# 99999       716      204       5  879795543
# 100000      276     1090       1  874795795
# 100001       13      225       2  882399156
# 100002       12      203       3  879959583
#
# [100003 rows x 4 columns]

# %%
movie_titles = pd.read_csv('Movie_Id_Titles')

# %% [markdown]
# movie_titles

# %%
movie_titles
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
# merge the titles on id

# %%
df = pd.merge(df, movie_titles, on="item_id")

# %%
df
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# ...         ...      ...     ...        ...
# 99998       840     1674       4  891211682
# 99999       655     1640       3  888474646
# 100000      655     1637       3  888984255
# 100001      655     1630       3  887428735
# 100002      655     1641       3  887427810
#
#                                                     title
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# ...

# %%
df = pd.merge(df, movie_titles, on="item_id")

# %%
df.drop('title_x', axis=1, inplace=True)

# %%
df
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# ...         ...      ...     ...        ...
# 99998       840     1674       4  891211682
# 99999       655     1640       3  888474646
# 100000      655     1637       3  888984255
# 100001      655     1630       3  887428735
# 100002      655     1641       3  887427810
#
#                                                   title_y
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# ...

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp           title_y
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.rename(columns={'title_y':'title'},inplace=True)

# %%
sns.set_style('white')
df
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# ...         ...      ...     ...        ...
# 99998       840     1674       4  891211682
# 99999       655     1640       3  888474646
# 100000      655     1637       3  888984255
# 100001      655     1630       3  887428735
# 100002      655     1641       3  887427810
#
#                                                     title
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# ...

# %%
# %matplotlib inline

# %%
#group by the title column
df.groupby('title')['rating'].mean()
# Out:
# title
# 'Til There Was You (1997)                2.333333
# 1-900 (1994)                             2.600000
# 101 Dalmatians (1996)                    2.908257
# 12 Angry Men (1957)                      4.344000
# 187 (1997)                               3.024390
#                                            ...
# Young Guns II (1990)                     2.772727
# Young Poisoner's Handbook, The (1995)    3.341463
# Zeus and Roxanne (1997)                  2.166667
# unknown                                  3.444444
# Á köldum klaka (Cold Fever) (1994)       3.000000
# Name: rating, Length: 1664, dtype: float64

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False)
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Prefontaine (1997)                              5.0
# Santa with Muscles (1996)                       5.0
# Star Kid (1997)                                 5.0
# Someone Else's America (1995)                   5.0
#                                                ...
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# JLG/JLG - autoportrait de décembre (1994)       1.0
# Daens (1992)                                    1.0
# Butterfly Kiss (1995)                           1.0
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# Name: rating, Length: 1664, dtype: float64

# %%
worst = df.groupby('title')['rating'].mean().sort_values(ascending=True)

# %%
df.groupby('title')['rating'].max()
# Out:
# title
# 'Til There Was You (1997)                4
# 1-900 (1994)                             4
# 101 Dalmatians (1996)                    5
# 12 Angry Men (1957)                      5
# 187 (1997)                               5
#                                         ..
# Young Guns II (1990)                     5
# Young Poisoner's Handbook, The (1995)    5
# Zeus and Roxanne (1997)                  3
# unknown                                  5
# Á köldum klaka (Cold Fever) (1994)       3
# Name: rating, Length: 1664, dtype: int64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
df_rating = df.groupby('rating').mean()

# %%
df_rating
# Out:
#            user_id     item_id     timestamp
# rating
# 1       433.368843  576.402389  8.836800e+08
# 2       472.553298  503.634477  8.837664e+08
# 3       473.030061  457.358077  8.835474e+08
# 4       464.684175  395.132615  8.833652e+08
# 5       448.366222  348.365892  8.835976e+08

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ratings.columns
# Out:
# Index(['rating'], dtype='object')

# %%
ratings.iplot()
# Out:
# <div>
#
#
#             <div id="25ae63b8-72f8-41fb-9e99-375259cf978b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("25ae63b8-72f8-41fb-9e99-375259cf978b")) {
#                     Plotly.newPlot(
#                         '25ae63b8-72f8-41fb-9e99-375259cf978b',
# ...

# %%
ratings['rating'].hist(bins=70)
ratings
# Out:
#                                          rating
# title
# 'Til There Was You (1997)              2.333333
# 1-900 (1994)                           2.600000
# 101 Dalmatians (1996)                  2.908257
# 12 Angry Men (1957)                    4.344000
# 187 (1997)                             3.024390
# ...                                         ...
# Young Guns II (1990)                   2.772727
# Young Poisoner's Handbook, The (1995)  3.341463
# Zeus and Roxanne (1997)                2.166667
# unknown                                3.444444
# Á köldum klaka (Cold Fever) (1994)     3.000000
#
# [1664 rows x 1 columns]

# %%
ratad = df.groupby('rating')['title']

# %%
ratings['num of ratings'] = df.groupby('title')['rating'].count()

# %%
ratings.columns
# Out:
# Index(['rating', 'num of ratings'], dtype='object')

# %%
sns.jointplot(x='rating',y='num of ratings', data= ratings, alpha=0.32, color='orange')

# %% [markdown]
# # Second part

# %%
movie_mat = df.pivot_table(index='user_id', columns='title', values='rating')

# %%
movie_mat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
ratings.sort_values('num of ratings', ascending= False)
# Out:
#                                       rating  num of ratings
# title
# Star Wars (1977)                    4.359589             584
# Contact (1997)                      3.803536             509
# Fargo (1996)                        4.155512             508
# Return of the Jedi (1983)           4.007890             507
# Liar Liar (1997)                    3.156701             485
# ...                                      ...             ...
# Great Day in Harlem, A (1994)       5.000000               1
# Other Voices, Other Rooms (1997)    3.000000               1
# Good Morning (1971)                 1.000000               1
# Girls Town (1996)                   3.000000               1
# Á köldum klaka (Cold Fever) (1994)  3.000000               1
#
# [1664 rows x 2 columns]

# %%
starwars_user_ratings = movie_mat['Star Wars (1977)']

# %%
liar_user_ratings = movie_mat['Liar Liar (1997)']

# %%
# user id with rating or NaN or a rating
starwars_user_ratings
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
#       ...
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
# now let's do a correlation with corr

# %%
#compute with two df objects
similar_to_starwars = movie_mat.corrwith(starwars_user_ratings)
# Out:
# /Users/aissata/opt/anaconda3/envs/cuffo/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /Users/aissata/opt/anaconda3/envs/cuffo/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning:
#
# divide by zero encountered in true_divide

# %%
#how correlated are other movies to star wars?
similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
similar_to_liar = movie_mat.corrwith(liar_user_ratings)

# %%
similar_to_liar
# Out:
# title
# 'Til There Was You (1997)                0.118913
# 1-900 (1994)                                  NaN
# 101 Dalmatians (1996)                    0.469765
# 12 Angry Men (1957)                      0.066272
# 187 (1997)                               0.175145
#                                            ...
# Young Guns II (1990)                     0.352174
# Young Poisoner's Handbook, The (1995)    0.445016
# Zeus and Roxanne (1997)                 -0.500000
# unknown                                  0.870388
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
#here we make dataframe with 
corr_starwars = pd.DataFrame(similar_to_starwars, columns=['Correlation'])
corr_starwars.dropna(inplace=True)

# %%
corr_starwars
# Out:
#                                        Correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns (1988)                         0.186377
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
#
# [1410 rows x 1 columns]

# %%
corr_starwars.sort_values('Correlation', ascending=False)
# Out:
#                             Correlation
# title
# Commandments (1997)                 1.0
# Cosi (1996)                         1.0
# No Escape (1994)                    1.0
# Stripes (1981)                      1.0
# Man of the Year (1995)              1.0
# ...                                 ...
# For Ever Mozart (1996)             -1.0
# Frankie Starlight (1995)           -1.0
# I Like It Like That (1994)         -1.0
# American Dream (1990)              -1.0
# Theodore Rex (1995)                -1.0
#
# [1410 rows x 1 columns]

# %%
#join on title name apparently
corr_starwars = corr_starwars.join(ratings['num of ratings'])

# %%
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation', ascending=False)
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
# ...                                                         ...
# Edge, The (1997)                                      -0.127167
# As Good As It Gets (1997)                             -0.130466
# Crash (1996)                                          -0.148507
# G.I. Jane (1997)                                      -0.176734
# First Wives Club, The (1996)                          -0.194496
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# ...

# %%
corr_liar = pd.DataFrame(similar_to_liar, columns=['Correlation'])

# %%
# create a nice looking data frame, with index and correlation

# %%
corr_liar.dropna(inplace=True)

# %%
corr_liar = corr_liar.join(ratings['num of ratings'])

# %%
corr_liar
# Out:
#                                        Correlation  num of ratings
# title
# 'Til There Was You (1997)                 0.118913               9
# 101 Dalmatians (1996)                     0.469765             109
# 12 Angry Men (1957)                       0.066272             125
# 187 (1997)                                0.175145              41
# 2 Days in the Valley (1996)               0.040739              93
# ...                                            ...             ...
# Young Guns (1988)                         0.410988             101
# Young Guns II (1990)                      0.352174              44
# Young Poisoner's Handbook, The (1995)     0.445016              41
# Zeus and Roxanne (1997)                  -0.500000               6
# unknown                                   0.870388               9
#
# [1375 rows x 2 columns]

# %%
# set a rating treshold, and then sort values by correlations
corr_liar[corr_liar['num of ratings']>100].sort_values('Correlation', ascending=False)
# Out:
#                                                     Correlation  \
# title
# Liar Liar (1997)                                       1.000000
# Batman Forever (1995)                                  0.516968
# Mask, The (1994)                                       0.484650
# Down Periscope (1996)                                  0.472681
# Con Air (1997)                                         0.469828
# ...                                                         ...
# Hoop Dreams (1994)                                    -0.184503
# Ed Wood (1994)                                        -0.199481
# Dr. Strangelove or: How I Learned to Stop Worry...    -0.238092
# Welcome to the Dollhouse (1995)                       -0.254231
# Raging Bull (1980)                                    -0.308129
#
#                                                     num of ratings
# title
# Liar Liar (1997)                                               485
# ...
